# %% [markdown]
# **For single video's comment extraction, we can use the following Python script.**

# %%
dev = "AIzaSyA72LL5ASeFWI2ZgjO8bGIZ7RlDbs4fy30"

# %%
import googleapiclient.discovery
import pandas as pd

api_service_name = "youtube"
api_version = "v3"
DEVELOPER_KEY = dev

youtube = googleapiclient.discovery.build(
    api_service_name, api_version, developerKey=DEVELOPER_KEY)

request = youtube.commentThreads().list(
    part="snippet",
    videoId="WPxfbxbE9ak",
    maxResults=100
)

comments = []

# Execute the request.
response = request.execute()

# Get the comments from the response.
for item in response['items']:
    comment = item['snippet']['topLevelComment']['snippet']
    public = item['snippet']['isPublic']
    comments.append([
        comment['authorDisplayName'],
        comment['publishedAt'],
        comment['likeCount'],
        comment['textOriginal'],
        public
    ])

while (1 == 1):
  try:
   nextPageToken = response['nextPageToken']
  except KeyError:
   break
  nextPageToken = response['nextPageToken']
  # Create a new request object with the next page token.
  nextRequest = youtube.commentThreads().list(part="snippet", videoId="-GJgqIJsTME", maxResults=100, pageToken=nextPageToken)
  # Execute the next request.
  response = nextRequest.execute()
  # Get the comments from the next response.
  for item in response['items']:
    comment = item['snippet']['topLevelComment']['snippet']
    public = item['snippet']['isPublic']
    comments.append([
        comment['authorDisplayName'],
        comment['publishedAt'],
        comment['likeCount'],
        comment['textOriginal'],
        public
    ])

df = pd.DataFrame(comments, columns=['author', 'updated_at', 'like_count', 'text','public'])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 793 entries, 0 to 792
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   author      793 non-null    object
#  1   updated_at  793 non-null    object
#  2   like_count  793 non-null    int64
#  3   text        793 non-null    object
#  4   public      793 non-null    bool
# dtypes: bool(1), int64(1), object(3)
# memory usage: 25.7+ KB

# %%
if response['items']:
    response['items'][0]
else:
    print("The 'items' list in the response is empty. No comments were retrieved for the video ID used in the last API call.")

# %%
df.head(20)
# Out:
#                      author            updated_at  like_count  \
# 0               @NooneTasin  2026-05-15T06:21:48Z           0
# 1          @porbomendas1740  2026-05-15T04:57:08Z           0
# 2            @AlifBinAshraf  2026-05-12T02:30:47Z           0
# 3                @সুপ্তসজিব  2026-05-11T16:54:45Z           0
# 4               @HappyKitun  2026-05-11T15:37:33Z           0
# 5    @sheikhraseldhaka-1383  2026-05-10T15:49:35Z           0
# 6          @MafujSheikh-q1c  2026-05-10T12:51:03Z           0
# 7          @SamiUllah-q4p7w  2026-05-09T22:04:48Z           0
# 8   @Ayeshaakterarifa-u2t1j  2026-05-09T15:24:42Z           0
# 9                 @SocR-t2x  2026-05-08T21:09:26Z           0
# 10       @ShantaAktar-q7n3m  2026-05-07T03:51:30Z           0
# 11         @TanvirIslam-j6n  2026-05-05T17:50:04Z           0
# 12         @sabbirrahman855  2026-05-05T06:01:57Z           1
# 13          @rockisback6449  2026-05-01T08:45:54Z           0
# ...

# %%
df.sort_values(by='like_count', ascending=False)[0:30]
# Out:
#                       author            updated_at  like_count  \
# 777              @Slickvic97  2023-10-23T15:05:54Z        1125
# 680           @Nolanbrown480  2023-10-23T16:59:12Z         783
# 645      @ActionBronsonMusic  2023-10-23T17:53:02Z         614
# 782          @uknownutin3528  2023-10-23T15:01:03Z         556
# 791                 @2xW-Man  2023-10-23T12:30:09Z         283
# 731           @urbanprojectz  2023-10-23T15:59:02Z         184
# 661        @yorkshireguy6671  2023-10-23T17:15:43Z          79
# 755  @elmejortrabajodelmundo  2023-10-23T15:26:47Z          77
# 790               @cheng8841  2023-10-23T12:57:26Z          70
# 741       @Raisinsetmelodies  2023-10-23T15:42:38Z          52
# 679              @JohnMHatch  2023-10-23T16:59:39Z          50
# 759          @InspectahReese  2023-10-23T15:25:27Z          48
# 696              @gijoey5912  2023-10-23T16:43:41Z          30
# 397                @hris1473  2023-10-24T18:35:58Z          25
# ...

# %%
df = pd.DataFrame(comments)

# Export to Excel
df.to_excel("Dukkho Bilash V-1.xlsx", index=False)

# %%
from google.colab import files

files.download("Dukkho Bilash V-1.xlsx.xlsx")
